# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import pandas as pd
import requests
from datetime import datetime

# %%
raw= requests.get("https://services1.arcgis.com/0MSEUqKaxRlEPj5g/arcgis/rest/services/Coronavirus_2019_nCoV_Cases/FeatureServer/1/query?where=1%3D1&outFields=*&outSR=4326&f=json")
raw_json = raw.json()
df = pd.DataFrame(raw_json["features"])

# %%
df.head()
# Out:
#                                           attributes  \
# 0  {'OBJECTID': 1, 'Province_State': None, 'Count...
# 1  {'OBJECTID': 2, 'Province_State': None, 'Count...
# 2  {'OBJECTID': 3, 'Province_State': None, 'Count...
# 3  {'OBJECTID': 4, 'Province_State': None, 'Count...
# 4  {'OBJECTID': 5, 'Province_State': None, 'Count...
#
#                                             geometry
# 0   {'x': 67.70995300000004, 'y': 33.93911000000003}
# 1  {'x': 20.168300000000045, 'y': 41.15330000000006}
# 2  {'x': 1.6596000000000686, 'y': 28.033900000000...
# 3  {'x': 1.5218000000000416, 'y': 42.50630000000007}
# 4  {'x': 17.87390000000005, 'y': -11.202699999999...

# %%
df["attributes"][0]
# Out:
# {'OBJECTID': 1,
#  'Province_State': None,
#  'Country_Region': 'Afghanistan',
#  'Last_Update': 1613499924000,
#  'Lat': 33.93911,
#  'Long_': 67.709953,
#  'Confirmed': 55518,
#  'Recovered': 48514,
#  'Deaths': 2428,
#  'Active': 4576,
#  'Admin2': None,
#  'FIPS': None,
#  'Combined_Key': 'Afghanistan'}

# %%
data_list = df["attributes"].tolist()
df_final = pd.DataFrame(data_list)
df_final.set_index("OBJECTID")
df_final = df_final[["Country_Region", "Province_State", "Lat", "Long_", "Confirmed", "Deaths", "Recovered", "Last_Update"]]

# %%
df_final.head()
# Out:
#   Country_Region Province_State       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan           None  33.93911  67.709953      55518    2428
# 1        Albania           None  41.15330  20.168300      93850    1567
# 2        Algeria           None  28.03390   1.659600     111069    2945
# 3        Andorra           None  42.50630   1.521800      10538     107
# 4         Angola           None -11.20270  17.873900      20381     493
#
#    Recovered   Last_Update
# 0      48514  1.613500e+12
# 1      57736  1.613500e+12
# 2      76330  1.613500e+12
# 3       9965  1.613500e+12
# 4      18884  1.613500e+12

# %%
def convertTime(t):
    t = int(t)
    return datetime.fromtimestamp(t)

# %%
df_final = df_final.dropna(subset=["Last_Update"])
df_final["Province_State"].fillna(value="", inplace=True)

df_final["Last_Update"] = df_final["Last_Update"]/1000
df_final["Last_Update"] = df_final["Last_Update"].apply(convertTime)

# %%
df_final.head()
# Out:
#   Country_Region Province_State       Lat      Long_  Confirmed  Deaths  \
# 0    Afghanistan                 33.93911  67.709953      55518    2428
# 1        Albania                 41.15330  20.168300      93850    1567
# 2        Algeria                 28.03390   1.659600     111069    2945
# 3        Andorra                 42.50630   1.521800      10538     107
# 4         Angola                -11.20270  17.873900      20381     493
#
#    Recovered         Last_Update
# 0      48514 2021-02-16 13:25:24
# 1      57736 2021-02-16 13:25:24
# 2      76330 2021-02-16 13:25:24
# 3       9965 2021-02-16 13:25:24
# 4      18884 2021-02-16 13:25:24

# %%
df_total = df_final.groupby("Country_Region", as_index=False).agg(
    {
        "Confirmed" : "sum",
        "Deaths" : "sum",
        "Recovered" : "sum"
    }
)

df_total.head()
# Out:
#   Country_Region  Confirmed  Deaths  Recovered
# 0    Afghanistan      55518    2428      48514
# 1        Albania      93850    1567      57736
# 2        Algeria     111069    2945      76330
# 3        Andorra      10538     107       9965
# 4         Angola      20381     493      18884

# %%
total_confirmed = df_final["Confirmed"].sum()
total_recovered = df_final["Recovered"].sum()
total_death = df_final["Deaths"].sum()

# %%
df_top10 = df_total.nlargest(10, "Confirmed")
top10_countries_1 = df_top10["Country_Region"].tolist()
top10_confirmed = df_top10["Confirmed"].tolist()

df_top10 = df_total.nlargest(10, "Recovered")
top10_countries_2 = df_top10["Country_Region"].tolist()
top10_recovered = df_top10["Recovered"].tolist()

df_top10 = df_total.nlargest(10, "Deaths")
top10_countries_3 = df_top10["Country_Region"].tolist()
top10_deaths = df_top10["Deaths"].tolist()

# %%
fig = make_subplots(
    rows = 4, cols = 6,
    specs=[
            [{"type": "scattergeo", "rowspan": 4, "colspan": 3}, None, None, {"type": "indicator"}, {"type": "indicator"}, {"type": "indicator"} ],
            [    None, None, None,               {"type": "bar", "colspan":3}, None, None],
            [    None, None, None,              {"type": "bar", "colspan":3}, None, None],
            [    None, None, None,               {"type": "bar", "colspan":3}, None, None],
          ]
)

# %%
message = df_final["Country_Region"] + " " + df_final["Province_State"] + "<br>"
message += "Confirmed: " + df_final["Confirmed"].astype(str) + "<br>"
message += "Deaths: " + df_final["Deaths"].astype(str) + "<br>"
message += "Recovered: " + df_final["Recovered"].astype(str) + "<br>"
message += "Last updated: " + df_final["Last_Update"].astype(str)
df_final["text"] = message

# %%
fig.add_trace(
    go.Scattergeo(
        locationmode = "country names",
        lon = df_final["Long_"],
        lat = df_final["Lat"],
        hovertext = df_final["text"],
        showlegend=False,
        marker = dict(
            size = 10,
            opacity = 0.8,
            reversescale = True,
            autocolorscale = True,
            symbol = 'square',
            line = dict(
                width=1,
                color='rgba(102, 102, 102)'
            ),
            cmin = 0,
            color = df_final['Confirmed'],
            cmax = df_final['Confirmed'].max(),
            colorbar_title="Confirmed Cases<br>Latest Update",
            colorbar_x = -0.05
        )

    ),

    row=1, col=1
)
# Out:
# <div>                            <div id="8b6022c4-9ed8-4051-ab89-5578f6390f36" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b6022c4-9ed8-4051-ab89-5578f6390f36")) {                    Plotly.newPlot(                        "8b6022c4-9ed8-4051-ab89-5578f6390f36",                        [{"geo": "geo", "hovertext": ["Afghanistan <br>Confirmed: 55518<br>Deaths: 2428<br>Recovered: 48514<br>Last updated: 2021-02-16 13:25:24", "Albania <br>Confirmed: 93850<br>Deaths: 1567<br>Recovered: 57736<br>Last updated: 2021-02-16 13:25:24", "
: 413908<br>Last updated: 2021-02-16 13:25:24", "Azerbaijan <br>Confirmed: 232337<br>Deaths: 3185<br>Recovered: 226951<br>Last updated: 2021-02-16 13:25:24", "Bahamas <br>Confirmed: 8311<br>Deaths: 178<br>Recovered: 6931<br>Last updated: 2021-02-16 13:25:24", "Bahrain <br>Confirmed: 113590<br>Deaths: 406<br>Recovered: 105784<br>Last updated: 2021-02-16 13:25:24", "Bangladesh <br>Confirmed: 541434<br>Deaths: 8298<br>Recovered: 488621<br>Last updated: 2021-02-16 13:25:24", "Barbados <br>Confirmed: 2268<br>Deaths: 24<br>Recovered: 1639<br>Last updated: 2021-02-16 13:25:24", "Belarus <br>Confirmed: 270921<br>Deaths: 1867<br>Recovered: 260057<br>Last updated: 2021-02-16 13:25:24", "Belgium Antwerp<br>Confirmed: 92524<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Brussels<br>Confirmed: 91527<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium East Flanders<br>Confirmed: 78040<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Flemish Brabant<br>Confirmed: 56646<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Hainaut<br>Confirmed: 112898<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Liege<br>Confirmed: 103636<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Limburg<br>Confirmed: 36639<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Luxembourg<br>Confirmed: 20900<br>Deaths: 0<br>Recovered: 0<br>Last updated: 2021-02-16 13:25:24", "Belgium Namur<br>Confirmed: 38892<br>Deaths: 0<br>Re ...

# %%
fig.add_trace(
    go.Bar(
        x=top10_countries_1,
        y=top10_confirmed,
        name= "Confirmed Cases",
        marker=dict(color="Yellow"),
        showlegend=True,
    ),
    row=2, col=4
)

fig.add_trace(
    go.Bar(
        x=top10_countries_2,
        y=top10_recovered,
        name= "Recovered Cases",
        marker=dict(color="Green"),
        showlegend=True),
    row=3, col=4
)

fig.add_trace(
    go.Bar(
        x=top10_countries_3,
        y=top10_deaths,
        name= "Deaths Cases",
        marker=dict(color="crimson"),
        showlegend=True),
    row=4, col=4
)
# Out:
# <div>                            <div id="21025f2c-d646-4b56-bafc-606da9178e9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21025f2c-d646-4b56-bafc-606da9178e9c")) {                    Plotly.newPlot(                        "21025f2c-d646-4b56-bafc-606da9178e9c",                        [{"geo": "geo", "hovertext": ["Afghanistan <br>Confirmed: 55518<br>Deaths: 2428<br>Recovered: 48514<br>Last updated: 2021-02-16 13:25:24", "Albania <br>Confirmed: 93850<br>Deaths: 1567<br>Recovered: 57736<br>Last updated: 2021-02-16 13:25:24", "Algeria <br>Confirmed: 111069<br>Deaths: 2945<br>Recovered: 76330<br>Last updated: 2021-02-16 13:25:24", "Andorra <br>Confirmed: 10538<br>Deaths: 107<br>Recovered: 9965<br>Last updated: 2021-02-16 13:25:24", "Angola <br>Confirmed: 20381<br>Deaths: 493<br>Recovered: 18884<br>Last updated: 2021-02-16 13:25:24", "Antigua and Barbuda <br>Confirmed: 443<br>Deaths: 9<br>Recovered: 205<br>Last updated: 2021-02-16 13:25:24", "Argentina <br>Confirmed: 2029057<br>Deaths: 50327<br>Recovered: 1833442<br>Last updated: 2021-02-16 13:25:24", "Armenia <br>Confirmed: 169391<br>Deaths: 3150<br>Recovered: 161348<br>Last updated: 2