# %%
import sys 
print(sys.path)
# Out:
# ['', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python36.zip', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/lib-dynload', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/extensions', '/home/ubuntu/.ipython']

# %%
# !conda list
# Out:
# # packages in environment at /home/ubuntu/anaconda3/envs/pytorch_p36:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                        main
# absl-py                   0.11.0                   pypi_0    pypi
# alabaster                 0.7.12                   py36_0
# anaconda-client           1.7.2                    py36_0
# anaconda-project          0.8.4                      py_0
# argh                      0.26.2                   py36_0
# argparse                  1.4.0                    pypi_0    pypi
# asn1crypto                1.3.0                    py36_0
# astroid                   2.4.2                    pypi_0    pypi
# astropy                   4.0              py36h7b6447c_0
# atomicwrites              1.3.0                    py36_1
# attrs                     19.3.0                     py_0
# autopep8                  1.4.4                      py_0
# ...

# %%
import sys
sys.path.insert(0,'/home/ubuntu/anaconda3/envs/pytorch_p36')

# %%
print(sys.path)
# Out:
# ['/home/ubuntu/anaconda3/envs/pytorch_p36', '', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python36.zip', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/lib-dynload', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages', '/home/ubuntu/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/IPython/extensions', '/home/ubuntu/.ipython']

# %%
# You minght need to logout and login back to EC2 and run this entire notebook to make path stuff work

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --data training/dataset.yaml --cfg training/yolov5l.yaml --weights ''
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='Tesla V100-SXM2-16GB', total_memory=16160MB)
#
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='training/yolov5l.yaml', data='training/dataset.yaml', device='', epochs=300, evolve=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, logdir='runs/', multi_scale=False, name='', noautoanchor=False, nosave=False, notest=False, rect=False, resume=False, single_cls=False, sync_bn=False, total_batch_size=16, weights='', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/", view at http://localhost:6006/
# ...
